# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
df_train = pd.read_csv(r"D:\Projects\Titanic\train.csv")
df_test = pd.read_csv(r"D:\Projects\Titanic\test.csv")
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
men = df_train.loc[df_train.Sex == 'male']["Survived"]
Rate_men = sum(men) / len(men) * 100
print(Rate_men,"%")

women = df_train.loc[df_train.Sex == 'female']['Survived']
Rate_women = sum(women) / len(women)
print(Rate_women,"%")
# Out:
# 18.890814558058924 %
# 0.7420382165605095 %

# %%
y = df_train['Survived']
features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

X_train = df_train[features]
X_test = df_test[features]

X_train = X_train.fillna(X_train.median(numeric_only=True))
X_test = X_test.fillna(X_test.median(numeric_only=True))

X_train = pd.get_dummies( X_train,drop_first=True)
X_test = pd.get_dummies(X_test,drop_first=True)

X_train, X_test = X_train.align(X_test, join='left', axis=1, fill_value=0)


scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_50832\263980754.py in ?()
#       6
#       7 X_train = X_train.fillna(X_train.median(numeric_only=True))
#       8 X_test = X_test.fillna(X_test.median(numeric_only=True))
#       9
# ---> 10 X_train = pd.get_dummies( df_train[X_train],drop_first=True)
#      11 X_test = pd.get_dummies(df_test[X_test],drop_first=True)
#      12
#      13 scaler = StandardScaler()
#
# d:\Anaconda\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    3876             return self._getitem_slice(key)
#    3877
#    3878         # Do we have a (boolean) DataFrame?
#    3879         if isinstance(key, DataFrame):
# -> 3880             return self.where(key)
#    3881
#    3882         # Do we have a (boolean) 1d indexer?
#    3883         if com.is_bool_indexer(key):
#
# d:\Anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#   10611                         ChainedAssignmentError,
#   10612                         stacklevel=2,
#   10613                     )
#   10614         other = common.apply_if_callable(other, self)
# > 10615         return self._where(cond, other, inplace, axis, level)
#
# d:\Anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#   10317                     raise ValueError(msg.format(dtype=cond.dtype))
#   10318             else:
#   10319                 for _dt in cond.dtypes:
#   10320                     if not is_bool_dtype(_dt):
# > 10321                         raise ValueError(msg.format(dtype=_dt))
#   10322                 if cond._mgr.any_extension_types:
#   10323                     # GH51574: avoid object ndarray conversion later on
#   10324                     cond = cond._constructor(
#
# ValueError: Boolean array expected for the condition, not int64

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
# evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
